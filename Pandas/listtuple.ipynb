# %%
1.String commands

# %%
# String methods

a = "Arushi"
print(a.upper())
print(a.lower())

b = "    Arushi is studying at BKGC.   "
print(b.strip()) # remove unnecessay spaces at the beginning & ending


a = "Hello, World!"
print(a.replace("World", "Arushi"))


c = "My name is Arushi!"
print(c.split(" ")) # convert string to list
# Out:
# ARUSHI
# arushi
# Arushi is studying at BKGC.
# Hello, Arushi!
# ['My', 'name', 'is', 'Arushi!']

# %% [markdown]
# 2.Boolean commands

# %%
def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# YES!

# %% [markdown]
# 3.List command

# %%
mylist = ['apple', 'banana', 'cherry']
mylist[0] = 'kiwi'
print(mylist[1])
# Out:
# banana

# %% [markdown]
# 4.Tuples command

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>
